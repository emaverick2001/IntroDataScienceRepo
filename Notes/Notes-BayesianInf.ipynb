# %% [markdown]
# ## Bayesian inference
#
# ### Joint probability
# - The joint probability of two events A and B is the probability that both A and B occur.
# - The joint probability of A and B is denoted by P(A and B) or P(A ∩ B).
# - The joint probability of A and B can be written as P(A ∩ B) = P(A) * P(B|A) = P(B) * P(A|B).
#
# $P(A \cap B) = P(A) \cdot P(B|A) = P(B) \cdot P(A|B)$
#
# ### Conditional probability
# - The conditional probability of an event B is the probability that the event will occur given the knowledge that an event A has already occurred.
# - The conditional probability of B given A is denoted by P(B|A) and is defined as P(B|A) = P(A ∩ B) / P(A).
#
# $P(B|A) = \frac{P(A \cap B)}{P(A)}$
#
# ### Bayes' theorem
# - Bayes' theorem describes the probability of an event, based on prior knowledge of conditions that might be related to the event.
# - Bayes' theorem is stated mathematically as the following equation:
#
# $P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)}$
#
# Where:
# - P(A|B) is the probability of event A occurring given that event B has occurred.
# - P(B|A) is the probability of event B occurring given that event A has occurred.
# - P(A) and P(B) are the probabilities of observing A and B independently of each other; this is known as the marginal probability.
#
# ### Probability Densities
# - Bayes theroem can be extended to continuous random variables using probability densities.
# - probability densities are used to describe the likelihood of a continuous random variable taking on a given value.
# - probability values
# - for instance if y or x are desnity functions then the probability of y given x is given by:
#
# $P(y|x) = \frac{P(x|y) \cdot P(y)}{P(x)}$
#
# Where:
# - P(y|x) is the probability of y occurring given that x has occurred.
# - P(x|y) is the probability of x occurring given that y has occurred.
# - P(x) and P(y) are the probabilities of observing x and y independently of each other; this is known as the marginal probability.
#
# ### Probabilistic Models
# - Probabilistic models are used to represent the relationship between random variables in a domain.
# - A probabilistic model is a mathematical description of a random phenomenon.
#
# $p(\theta|D) = \frac{p(D|\theta) \cdot p(\theta)}{p(D)}$
#
# Where:
# - p(θ|D) is the posterior probability of the model parameters given the data.
# - p(D|θ) is the likelihood of the data given the model parameters.
# - p(θ) is the prior probability of the model parameters.
# - p(D) is the marginal likelihood of the data.
#
# $p(\theta|D, M) = \frac{p(D|\theta, M) \cdot p(\theta|M)}{p(D|M)}$
#
# Where:
# - p(θ|D, M) is the posterior probability of the model parameters given the data and the model.
# - p(D|θ, M) is the likelihood of the data given the model parameters and the model.
# - p(θ|M) is the prior probability of the model parameters given the model.
# - p(D|M) is the marginal likelihood of the data given the model.
#
# ### Likelihood Function
# - The likelihood function is a function of the parameters of a statistical model, given specific observed data.
# - The likelihood function is used to estimate the parameters of a statistical model.
# - The likelihood function is defined as the probability of the observed data given the model parameters.
# - a prior is
#
# $p(theta|D) = pi(theta) \cdot L(D|theta)/Z$
#
# $ Z = \int \pi(theta) \cdot L(theta) dtheta$
#
# Where:
# - p(θ|D) is the posterior probability of the model parameters given the data.
# - p(θ) is the prior probability of the model parameters.
# - L(D|θ) is the likelihood of the data given the model parameters.
# - Z is the marginal likelihood of the data.
#
# ### Parameterization
# - The likelihood function can be parameterized in different ways.
# - The likelihood function can be parameterized in terms of the model parameters or the data.
# -
